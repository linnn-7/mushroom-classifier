# %%
# !pip install kaggle

# %% [markdown]
# Upload kaggle token

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d maysee/mushrooms-classification-common-genuss-images
# !unzip mushrooms-classification-common-genuss-images.zip -d /content/data/

# %%
# !python3 /content/resnet_trainer.py
# Out:
# Skipping corrupted image: /content/data/Mushrooms/Russula/092_43B354vYxm8.jpg
# Total images: 6713
# Training images: 5370
# Validation images: 1343
# Classes: ['Agaricus', 'Amanita', 'Boletus', 'Cortinarius', 'Entoloma', 'Hygrocybe', 'Lactarius', 'Russula', 'Suillus']
# Using device: cuda
# /content/resnet_trainer.py:80: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
# /content/resnet_trainer.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():  # Mixed precision
# /content/resnet_trainer.py:116: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():  # Mixed precision
# ...

# %%
# !python3 nn_ablation_study.py
# Out:
# Running Experiment: Baseline (Aug + Dropout + AdamW)
# Skipping corrupted image: /content/data/Mushrooms/Russula/092_43B354vYxm8.jpg
# /content/nn_ablation_study.py:62: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
# /content/nn_ablation_study.py:71: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /content/nn_ablation_study.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Validation Accuracy for Baseline (Aug + Dropout + AdamW): 0.8042
#
# Running Experiment: No Augmentation
# Skipping corrupted image: /content/data/Mushrooms/Russula/092_43B354vYxm8.jpg
# Validation Accuracy for No Augmentation: 0.8153
#
# ...
